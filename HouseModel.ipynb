# %% [markdown]
# <a href="https://colab.research.google.com/github/Andres-Nicolas/CIP/blob/main/HouseModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
datos = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/housingData.csv")

# %%
datos.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
datos.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
datos.hist()
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
datos.hist("median_house_value")
# Out:
# array([[<Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
datos.hist("median_income")
# Out:
# array([[<Axes: title={'center': 'median_income'}>]], dtype=object)

# %%
datos.hist(figsize=(15,10), edgecolor='black', bins=10)
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
import seaborn as sb
sb.scatterplot(x="latitude", y="longitude", data=datos, hue="median_house_value", palette="coolwarm" )
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
sb.scatterplot(x="latitude", y="longitude", data=datos[(datos.median_income > 10)], hue="median_house_value", palette="coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %% [markdown]
# LIMPIAR DATOS

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
datosN=datos.dropna()
datosN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
#Dummies / One-Hot Encoding
dummies_ocean = pd.get_dummies(datosN["ocean_proximity"], dtype=int)
datosN.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
datosN = datosN.drop("ocean_proximity", axis=1)
datosN.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value
# 0       322.0       126.0         8.3252            452600.0
# 1      2401.0      1138.0         8.3014            358500.0
# 2       496.0       177.0         7.2574            352100.0
# 3       558.0       219.0         5.6431            341300.0
# 4       565.0       259.0         3.8462            342200.0

# %%
datosN.corr()
sb.set(rc={'figure.figsize': (15,8)})
sb.heatmap(datosN.corr(), annot=True, cmap="YlGnBu")
datosN.corr()["median_house_value"].sort_values(ascending=False)
# Out:
# median_house_value    1.000000
# median_income         0.688355
# total_rooms           0.133294
# housing_median_age    0.106432
# households            0.064894
# total_bedrooms        0.049686
# population           -0.025300
# longitude            -0.045398
# latitude             -0.144638
# Name: median_house_value, dtype: float64

# %%
X = datosN.drop("median_house_value", axis=1)
Y = datosN["median_house_value"]

from sklearn.model_selection import train_test_split
X_entrena, X_prueba, Y_entrena, Y_prueba = train_test_split(X, Y, test_size=.2)

from sklearn.linear_model import LinearRegression

modelo=LinearRegression()
modelo.fit(X_entrena, Y_entrena)

prediccion = modelo.predict(X_prueba)
print(prediccion)
# Out:
# [183851.77622853 244369.81238438 142096.62877933 ... 164565.6681428
#  236586.86463076  34136.05901796]

# %%
comparativa = {"Prediccion": prediccion, "Valor Real": Y_prueba}
pd.DataFrame(comparativa)
# Out:
#           Prediccion  Valor Real
# 7556   183851.776229    115800.0
# 3784   244369.812384    309400.0
# 19437  142096.628779    135600.0
# 1112    14346.256579     88300.0
# 16948  369304.170946    464600.0
# ...              ...         ...
# 5692   269845.648408    292100.0
# 892    299861.732051    259600.0
# 16592  164565.668143    134700.0
# 11538  236586.864631    186000.0
# 18741   34136.059018     69400.0
#
# [4087 rows x 2 columns]

# %%
print(modelo.score(X_prueba, Y_prueba))
print(modelo.score)
# Out:
# 0.6267006547646621
# <bound method RegressorMixin.score of LinearRegression()>

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(Y_prueba, prediccion)
mse
# Out:
# 4984118465.361301

# %%
# Evaluar el modelo con validación cruzada (métrica: error cuadratico)
from sklearn.model_selection import cross_val_score
scores = cross_val_score(modelo, X, Y, cv=10, scoring='neg_mean_squared_error')
scores
# Out:
# array([-4.43969398e+09, -3.99212587e+09, -7.85365045e+09, -3.33232071e+09,
#        -6.71745569e+09, -5.14355723e+09, -2.92422382e+09, -7.44010288e+09,
#        -6.01629313e+09, -3.04717234e+09])

# %%
import numpy as np
rmse_scores=np.sqrt(-scores)
rmse_scores
# Out:
# array([66631.02867795, 63183.27204236, 88620.82400015, 57726.25670986,
#        81960.08593309, 71718.5975369 , 54076.09288048, 86256.03098093,
#        77564.76732785, 55201.198732  ])

# %%
def mostrar(scores):
  print("Puntajes de RMSE en fold", scores)
  print("promedio de RMSE: ",np.mean(scores))
  print("Desviacion estandar de RMSE: ",np.std(scores))

mostrar(rmse_scores)
# Out:
# Puntajes de RMSE en fold [66631.02867795 63183.27204236 88620.82400015 57726.25670986
#  81960.08593309 71718.5975369  54076.09288048 86256.03098093
#  77564.76732785 55201.198732  ]
# promedio de RMSE:  70293.81548215677
# Desviacion estandar de RMSE:  12224.52923902532

# %% [markdown]
# #DESICIONTREE

# %%
from sklearn.tree import DecisionTreeRegressor
modelo2 = DecisionTreeRegressor(random_state=42)
modelo2.fit(X_entrena, Y_entrena)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(modelo2, X, Y, cv=10, scoring='neg_mean_squared_error')
scores
# Out:
# array([-2.02733530e+10, -7.71585914e+09, -1.04207158e+10, -5.70777701e+09,
#        -7.98145603e+09, -7.72269251e+09, -4.78334385e+09, -1.10367407e+10,
#        -1.17201234e+10, -5.83328215e+09])

# %%
import numpy as np
rmse_scores=np.sqrt(-scores)
rmse_scores
# Out:
# array([142384.52527654,  87839.96321215, 102081.90729237,  75549.83128492,
#         89338.99503118,  87878.85131886,  69161.72244036, 105055.89324028,
#        108259.51894571,  76375.92648199])

# %%
def mostrar(scores):
  print("Puntajes de RMSE en fold", scores)
  print("promedio de RMSE: ",np.mean(scores))
  print("Desviacion estandar de RMSE: ",np.std(scores))

mostrar(rmse_scores)
# Out:
# Puntajes de RMSE en fold [142384.52527654  87839.96321215 102081.90729237  75549.83128492
#   89338.99503118  87878.85131886  69161.72244036 105055.89324028
#  108259.51894571  76375.92648199]
# promedio de RMSE:  94392.71345243455
# Desviacion estandar de RMSE:  20237.342058435308

# %% [markdown]
# #randomforest

# %%
from sklearn.ensemble import RandomForestRegressor
modelo3 = RandomForestRegressor(n_estimators=100, random_state=42)
modelo3.fit(X_entrena, Y_entrena)
# Out:
# RandomForestRegressor(random_state=42)

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(modelo3, X, Y, cv=10, scoring='neg_mean_squared_error')
scores
# Out:
# array([-9.31785543e+09, -4.01227752e+09, -4.64931123e+09, -2.80289628e+09,
#        -4.08608750e+09, -4.54302115e+09, -2.75589011e+09, -6.58033807e+09,
#        -7.47771119e+09, -2.94330542e+09])

# %%
rmse_scores=np.sqrt(-scores)
rmse_scores
# Out:
# array([96529.03930222, 63342.54118887, 68185.85801258, 52942.38646852,
#        63922.51167675, 67401.93730398, 52496.57238451, 81119.28295855,
#        86473.760122  , 54252.23889242])

# %%
def mostrar(scores):
  print("Puntajes de RMSE en fold", scores)
  print("promedio de RMSE: ",np.mean(scores))
  print("Desviacion estandar de RMSE: ",np.std(scores))

mostrar(rmse_scores)
# Out:
# Puntajes de RMSE en fold [96529.03930222 63342.54118887 68185.85801258 52942.38646852
#  63922.51167675 67401.93730398 52496.57238451 81119.28295855
#  86473.760122   54252.23889242]
# promedio de RMSE:  68666.6128310394
# Desviacion estandar de RMSE:  14204.424450114873

# %%
# Datos de evaluación
list_model = ['Linear Regression', 'DecisionTree', 'Random Forest']
list_mean = [70293.81548215677, 94392.71345243455, 68666.6128310394]
list_sd = [12224.52923902532, 20237.342058435308, 14204.424450114873]

# Agregamos una gráfica para comparar visualmente los resultados
import matplotlib.pyplot as plt

plt.figure(figsize=(4, 5))
for i in range(3):
    plt.errorbar(i, list_mean[i], xerr=0, yerr=list_sd[i], fmt='o', linewidth=3)

plt.xticks([0, 1, 2], list_model)
plt.title("Evaluación de los modelos")
plt.ylim(0, 120000)
plt.grid(visible=True, which='major', color='#666666', linestyle='-')
plt.minorticks_on()
plt.grid(visible=True, which='minor', color='#999999', linestyle='-', alpha=0.2)
plt.show()

# %%
datosN.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value
# 0       322.0       126.0         8.3252            452600.0
# 1      2401.0      1138.0         8.3014            358500.0
# 2       496.0       177.0         7.2574            352100.0
# 3       558.0       219.0         5.6431            341300.0
# 4       565.0       259.0         3.8462            342200.0

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_entrena_scaled = scaler.fit_transform(X_entrena)
X_prueba_scaled = scaler.transform(X_prueba)
pd.DataFrame(X_entrena_scaled)
# Out:
#               0         1         2         3         4         5         6  \
# 0      0.949372 -0.736333 -0.206821 -0.476429 -0.257975 -0.218785 -0.351654
# 1     -1.033962  1.646275 -1.082668  0.008265 -0.336292 -0.239433 -0.241529
# 2      0.754536 -0.811229  0.669026 -0.672214 -0.673291 -0.488105 -0.689898
# 3      1.304074 -1.335496 -0.206821  0.075495  0.219044  0.322549  0.212085
# 4      0.824477 -0.726971  0.509781 -0.337880 -0.538016 -0.413593 -0.461780
# ...         ...       ...       ...       ...       ...       ...       ...
# 16341  0.609658 -0.689524  1.306006 -0.568189 -0.609213 -0.796925 -0.600748
# 16342  0.964360 -0.755057 -1.799270 -1.086952 -1.164549 -1.173076 -1.198574
# 16343 -1.253777  0.976898  0.191292  0.556555 -0.015906 -0.051806  0.057384
# 16344  0.639632 -0.890805  0.111669  0.088214  0.411275  0.218411  0.400872
# 16345 -1.373676  0.887960  0.828271  0.070044 -0.174912 -0.217887 -0.147135
#
#               7
# 0     -0.744973
# 1      0.713659
# ...

# %% [markdown]
# #linear regresion

# %%
from sklearn.model_selection import train_test_split
X_entrena, X_prueba, Y_entrena, Y_prueba = train_test_split(X, Y, test_size=.2)

from sklearn.linear_model import LinearRegression

modelo4=LinearRegression()
modelo4.fit(X_entrena_scaled, Y_entrena)

prediccion = modelo4.predict(X_prueba_scaled)
print(prediccion)
# Out:
# [206987.35542321 205852.75959273 205599.57287645 ... 205421.8946172
#  207334.97924943 202982.60191434]

# %%
# Evaluar el modelo con validación cruzada (métrica: error cuadratico)
from sklearn.model_selection import cross_val_score
scores = cross_val_score(modelo4, X_prueba_scaled, Y_prueba, cv=10, scoring='neg_mean_squared_error')
scores
# Out:
# array([-1.24336714e+10, -1.25055609e+10, -1.39901713e+10, -1.36851845e+10,
#        -1.13703962e+10, -1.35245934e+10, -1.27509419e+10, -1.36703837e+10,
#        -1.29481601e+10, -1.34731643e+10])

# %%
import numpy as np
rmse_scores=np.sqrt(-scores)
rmse_scores
# Out:
# array([111506.37380336, 111828.26508564, 118280.05450352, 116983.69324714,
#        106632.06001206, 116295.28553401, 112920.06883003, 116920.41627917,
#        113789.98227912, 116073.96025887])

# %%
def mostrar(scores):
  print("Puntajes de RMSE en fold", scores)
  print("promedio de RMSE: ",np.mean(scores))
  print("Desviacion estandar de RMSE: ",np.std(scores))

mostrar(rmse_scores)
# Out:
# Puntajes de RMSE en fold [111506.37380336 111828.26508564 118280.05450352 116983.69324714
#  106632.06001206 116295.28553401 112920.06883003 116920.41627917
#  113789.98227912 116073.96025887]
# promedio de RMSE:  114123.01598329101
# Desviacion estandar de RMSE:  3340.657768971789

# %% [markdown]
# #desicion tree

# %%
from sklearn.tree import DecisionTreeRegressor
modelo5 = DecisionTreeRegressor(random_state=42)
modelo5.fit(X_entrena_scaled, Y_entrena)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(modelo5, X_prueba_scaled, Y_prueba, cv=10, scoring='neg_mean_squared_error')
scores
# Out:
# array([-2.78597607e+10, -2.46653394e+10, -3.17061805e+10, -2.79626938e+10,
#        -2.46457177e+10, -2.75333899e+10, -2.42859899e+10, -2.97419585e+10,
#        -2.61656338e+10, -2.69978884e+10])

# %%
import numpy as np
rmse_scores=np.sqrt(-scores)
rmse_scores
# Out:
# array([166912.4343157 , 157052.02760125, 178062.29388969, 167220.49461174,
#        156989.54651658, 165931.88320264, 155839.62882727, 172458.57033494,
#        161757.94831996, 164310.34168426])

# %%
def mostrar(scores):
  print("Puntajes de RMSE en fold", scores)
  print("promedio de RMSE: ",np.mean(scores))
  print("Desviacion estandar de RMSE: ",np.std(scores))

mostrar(rmse_scores)
# Out:
# Puntajes de RMSE en fold [166912.4343157  157052.02760125 178062.29388969 167220.49461174
#  156989.54651658 165931.88320264 155839.62882727 172458.57033494
#  161757.94831996 164310.34168426]
# promedio de RMSE:  164653.51693040217
# Desviacion estandar de RMSE:  6758.30047818658

# %% [markdown]
# #RandomForest

# %%
from sklearn.ensemble import RandomForestRegressor
modelo6 = RandomForestRegressor(n_estimators=100, random_state=42)
modelo6.fit(X_entrena_scaled, Y_entrena)
# Out:
# RandomForestRegressor(random_state=42)

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(modelo6, X_prueba_scaled, Y_prueba, cv=10, scoring='neg_mean_squared_error')
scores
# Out:
# array([-1.31230203e+10, -1.30611660e+10, -1.46002042e+10, -1.45241061e+10,
#        -1.17871587e+10, -1.41040695e+10, -1.36217040e+10, -1.46598817e+10,
#        -1.31977646e+10, -1.40115624e+10])

# %%
rmse_scores=np.sqrt(-scores)
rmse_scores
# Out:
# array([114555.75207718, 114285.45855236, 120831.3048816 , 120515.99917176,
#        108568.68212399, 118760.55512164, 116712.05581558, 121077.99835268,
#        114881.52420167, 118370.44583713])

# %%
def mostrar(scores):
  print("Puntajes de RMSE en fold", scores)
  print("promedio de RMSE: ",np.mean(scores))
  print("Desviacion estandar de RMSE: ",np.std(scores))

mostrar(rmse_scores)
# Out:
# Puntajes de RMSE en fold [114555.75207718 114285.45855236 120831.3048816  120515.99917176
#  108568.68212399 118760.55512164 116712.05581558 121077.99835268
#  114881.52420167 118370.44583713]
# promedio de RMSE:  116855.97761355923
# Desviacion estandar de RMSE:  3707.3241745748924

# %% [markdown]
# # Datos de evaluación

# %%
list_model = ['Modelo', 'Modelo2', 'Modelo3','Modelo4','Modelo5','Modelo6']
list_mean = [70293.81548215677,94392.71345243455,68666.6128310394,114123.01598329101, 164653.51693040217, 116855.97761355923]
list_sd = [12224.52923902532,20237.342058435308,14204.424450114873,3340.657768971789, 6758.30047818658, 3707.3241745748924]

# Agregamos una gráfica para comparar visualmente los resultados
import matplotlib.pyplot as plt

plt.figure(figsize=(7, 6))
for i in range(6):
    plt.errorbar(i, list_mean[i], xerr=0, yerr=list_sd[i], fmt='o', linewidth=3)
plt.xticks([0, 1, 2,3,4,5], list_model)
plt.title("Evaluación de los modelos")
plt.ylim(0, 200000)
plt.grid(visible=True, which='major', color='#666666', linestyle='-')
plt.minorticks_on()
plt.grid(visible=True, which='minor', color='#999999', linestyle='-', alpha=0.2)
plt.show()

# %%
print("modelo 1 ",modelo.score(X,Y))
print("modelo 2 ",modelo2.score(X,Y))
print("modelo 3 ",modelo3.score(X,Y))
print("modelo 4 ",modelo4.score(X_prueba_scaled,Y_prueba))
print("modelo 5 ",modelo5.score(X_prueba_scaled,Y_prueba))
print("modelo 6 ",modelo6.score(X_prueba_scaled,Y_prueba))
# Out:
# modelo 1  0.6366487567962347
# modelo 2  0.9276211087261763
# modelo 3  0.9428766809481093
# modelo 4  -0.00024470416169153353
# modelo 5  -1.1837126059440521
# modelo 6  -0.06371819483086716

# %% [markdown]
# #Fine_Tuning

# %%
from sklearn.model_selection import GridSearchCV
#forest_reg = RandomForestRegressor()
# Definimos los posibles parámetros
n_estimators = [3, 10, 30, 50, 80, 100]
min_samples_split = [2, 4, 6, 8]
max_depth = [2, 4, 6, 8, 10]

params = {
    'n_estimators': n_estimators,
    'min_samples_split': min_samples_split,
    'max_depth': max_depth
}


#Aplicamos el método de ajuste

grid_search = GridSearchCV(estimator=modelo6, param_grid=params, cv=10, scoring='neg_mean_squared_error')
grid_search.fit(X_prueba_scaled, Y_prueba)
# Out:
# GridSearchCV(cv=10, estimator=RandomForestRegressor(random_state=42),
#              param_grid={'max_depth': [2, 4, 6, 8, 10],
#                          'min_samples_split': [2, 4, 6, 8],
#                          'n_estimators': [3, 10, 30, 50, 80, 100]},
#              scoring='neg_mean_squared_error')

# %%
# Vemos los mejores parámetros encontrados

print("Mejores parámetros:", grid_search.best_params_)
# Out:
# Mejores parámetros: {'max_depth': 2, 'min_samples_split': 2, 'n_estimators': 30}
